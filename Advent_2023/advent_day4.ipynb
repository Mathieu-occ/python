# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('advent_day4.txt', sep="\s+", header=None)
# part1


#print(data[1][0])
scoretotal = 0

for linecpt in range(196):
    cpt = 0
    totalligne=0
    for i in range(25):
        for j in range(10):
            if data[j+2][linecpt]==data[i+13][linecpt]:
                cpt = cpt+1
                totalligne = pow(2,cpt-1)
                
    scoretotal = scoretotal+totalligne
                
    print("linecpt",linecpt,"cpt",cpt,"totalligne",totalligne)
print("scoretotal",scoretotal)
# Out:
# linecpt 0 cpt 10 totalligne 512
# linecpt 1 cpt 10 totalligne 512
# linecpt 2 cpt 5 totalligne 16
# linecpt 3 cpt 9 totalligne 256
# linecpt 4 cpt 2 totalligne 2
# linecpt 5 cpt 9 totalligne 256
# linecpt 6 cpt 9 totalligne 256
# linecpt 7 cpt 0 totalligne 0
# linecpt 8 cpt 10 totalligne 512
# linecpt 9 cpt 1 totalligne 1
# linecpt 10 cpt 8 totalligne 128
# linecpt 11 cpt 9 totalligne 256
# linecpt 12 cpt 1 totalligne 1
# linecpt 13 cpt 0 totalligne 0
# linecpt 14 cpt 1 totalligne 1
# linecpt 15 cpt 4 totalligne 8
# linecpt 16 cpt 0 totalligne 0
# linecpt 17 cpt 2 totalligne 2
# linecpt 18 cpt 2 totalligne 2
# linecpt 19 cpt 1 totalligne 1
# linecpt 20 cpt 0 totalligne 0
# linecpt 21 cpt 10 totalligne 512
# linecpt 22 cpt 10 totalligne 512
# linecpt 23 cpt 10 totalligne 512
# linecpt 24 cpt 1 totalligne 1
# linecpt 25 cpt 10 totalligne 512
# linecpt 26 cpt 10 totalligne 512
# linecpt 27 cpt 10 totalligne 512
# linecpt 28 cpt 8 totalligne 128
# linecpt 29 cpt 10 totalligne 512
# ...

# %%
#part2

#scoretotal = 0

for linecpt in range(2): # remettre 196
    cpt = 0
    totalligne=0
    for i in range(25):
        for j in range(10):
            if data[j+2][linecpt]==data[i+13][linecpt]:
                cpt = cpt+1
                
    for k in range(cpt):
        data[39][linecpt+k]=data[39][linecpt+k]+1



    print("linecpt",linecpt,"cpt",cpt, "nbcartes",)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 39
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 14
#      11             cpt = cpt+1
#      13 for k in range(cpt):
# ...
